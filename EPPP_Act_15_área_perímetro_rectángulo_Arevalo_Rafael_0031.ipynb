# %% [markdown]
# <a href="https://colab.research.google.com/github/ArevaloMurguia/EPPP-Act-15-rea-per-metro-rect-ngulo-Arevalo-Rafael-0031/blob/main/EPPP_Act_15_%C3%A1rea_per%C3%ADmetro_rect%C3%A1ngulo_Arevalo_Rafael_0031.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Arevalo Rafael NL = 3 NC = 2530805128**0031** Fecha:13/Abr/26
# ### 🟫 Cálculos de un rectángulo
# #### 🧾 Redacción del problema
# #### Se requiere desarrollar un programa que permita calcular el área y el perímetro de un rectángulo.
#
# #### El programa debe mostrar un menú con opciones para seleccionar el tipo de cálculo. El usuario ingresará la base y la altura del rectángulo, y el sistema realizará la operación correspondiente.
#
# #### Se utilizarán estructuras de control como while para repetir el menú y if, elif, else para seleccionar la opción deseada.
#
# ### 🔹 Variables
# | Variable  | Descripción                  | Tipo   |
# | --------- | ---------------------------- | ------ |
# | base      | Base del rectángulo          | Real   |
# | altura    | Altura del rectángulo        | Real   |
# | area      | Resultado del área           | Real   |
# | perimetro | Resultado del perímetro      | Real   |
# | opcion    | Opción seleccionada del menú | Entero |
#
# ### 📐 Fórmulas
#
# * Área:
#
# base × altura
#
# * Perímetro:
#
#  2 × (base + altura)
#
#  <img src="https://raw.githubusercontent.com/ArevaloMurguia/EPPP-Act-15-rea-per-metro-rect-ngulo-Arevalo-Rafael-0031/refs/heads/main/R1.jfif" width="300" height="300" alt="Texto descriptivo">

# %%
# ╔══════════════════════════════════════════════╗
# ║        🟫 CÁLCULOS DE RECTÁNGULO 🟫          ║
# ║        Arevalo Rafael NL = 3                 ║
# ╚══════════════════════════════════════════════╝

# ════════════════ MENÚ ════════════════
def menu():
    print("\n╔════════════════════════════════════╗")
    print("║           📌 MENÚ PRINCIPAL        ║")
    print("╠════════════════════════════════════╣")
    print("║ 1️⃣  Área del rectángulo           ║")
    print("║ 2️⃣  Perímetro del rectángulo      ║")
    print("║ 3️⃣  Salir                         ║")
    print("╚════════════════════════════════════╝")


# ════════════════ ÁREA ════════════════
def arearectangulo():
    print("\n╔════════════════════════════════════╗")
    print("║        🟢 ÁREA DEL RECTÁNGULO      ║")
    print("╚════════════════════════════════════╝")

    base = float(input("🔹 Ingresa la base: "))
    altura = float(input("🔹 Ingresa la altura: "))

    area = base * altura

    print("\n╔════════ RESULTADO ════════╗")
    print(f"║ Base   : {base:<12} ║")
    print(f"║ Altura : {altura:<12} ║")
    print(f"║ Área   : {area:<12.2f} ║")
    print("╚══════════════════════════╝")


# ═══════════════ PERÍMETRO ═══════════════
def perimetrorectangulo():
    print("\n╔════════════════════════════════════╗")
    print("║     🔵 PERÍMETRO DEL RECTÁNGULO    ║")
    print("╚════════════════════════════════════╝")

    base = float(input("🔹 Ingresa la base: "))
    altura = float(input("🔹 Ingresa la altura: "))

    perimetro = 2 * (base + altura)

    print("\n╔════════ RESULTADO ════════╗")
    print(f"║ Base       : {base:<10} ║")
    print(f"║ Altura     : {altura:<10} ║")
    print(f"║ Perímetro  : {perimetro:<10.2f} ║")
    print("╚══════════════════════════╝")


# ═════════════ PROGRAMA PRINCIPAL ═════════════
while True:
    menu()
    opcion = int(input("👉 Selecciona una opción: "))

    if opcion == 1:
        arearectangulo()

    elif opcion == 2:
        perimetrorectangulo()

    elif opcion == 3:
        print("\n🚪 Cerrando programa...")
        break

    else:
        print("\n❌ Opción inválida, intenta de nuevo")

print("\n✔ Programa realizado por Arevalo Rafael NL = 3")5
5
# Out:
# ╔════════════════════════════════════╗
# ║           📌 MENÚ PRINCIPAL        ║
# ╠════════════════════════════════════╣
# ║ 1️⃣  Área del rectángulo           ║
# ║ 2️⃣  Perímetro del rectángulo      ║
# ║ 3️⃣  Salir                         ║
# ╚════════════════════════════════════╝
# 👉 Selecciona una opción: 1
#
# ╔════════════════════════════════════╗
# ║        🟢 ÁREA DEL RECTÁNGULO      ║
# ╚════════════════════════════════════╝
# 🔹 Ingresa la base: 5
# 🔹 Ingresa la altura: 5
#
# ╔════════ RESULTADO ════════╗
# ║ Base   : 5.0          ║
# ║ Altura : 5.0          ║
# ║ Área   : 25.00        ║
# ╚══════════════════════════╝
#
# ╔════════════════════════════════════╗
# ║           📌 MENÚ PRINCIPAL        ║
# ╠════════════════════════════════════╣
# ║ 1️⃣  Área del rectángulo           ║
# ║ 2️⃣  Perímetro del rectángulo      ║
# ║ 3️⃣  Salir                         ║
# ╚════════════════════════════════════╝
# 👉 Selecciona una opción: 2
#
# ╔════════════════════════════════════╗
# ...

# %% [markdown]
# <img src="https://raw.githubusercontent.com/ArevaloMurguia/EPPL-Act-14-menu-circulo-funciones-area-perimetro-y-volumen-Arevalo-Rafael/refs/heads/main/shapes%20at%2026-04-13%2013.18.28.png" width="900" height="900" alt="Texto descriptivo">
